# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/mosc_data.csv',sep=',',decimal='.')

# %%
df

# %%
plt.figure(figsize=(16,7))
plt.plot(df["value"],lw=1.5)
plt.xlabel("Numer pomiaru od 1960-01-01 do 2025-03-23 co 6 godzin")
plt.ylabel("mosc_data[value]")
plt.grid()
plt.show()
